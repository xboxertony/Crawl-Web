# %%
import pandas as pd
import requests as req
import numpy as np
import math

URV = 'https://rate.bot.com.tw/xrt?Lang=zh-TW'

s = req.get(URV)

df = pd.read_html(s.text)

columns = pd.MultiIndex.from_product([('現金匯率','即期匯率'),('本行買入','本行賣出')])

L = [i[:i.index(')')+1] for i in df[0][('幣別','幣別')].values]
df_coin = pd.DataFrame(df[0].iloc[:,1:5].values,columns = columns,index = L)
for i in range(len(df_coin.columns)):
    for j in range(len(df_coin.index)):
        if df_coin.iloc[j,i]!='-':
            df_coin.iloc[j,i] = float(df_coin.iloc[j,i])
        else:
            df_coin.iloc[j,i] = 1000000
            
df_coin['即期點差'] = (df_coin.iloc[:,3]-df_coin.iloc[:,2])/df_coin.iloc[:,3]
df_coin['即期點差'] = np.array([round(i,3) for i in df_coin['即期點差']])
df_coin
# Out:
#                現金匯率              即期匯率            即期點差
#                本行買入     本行賣出     本行買入     本行賣出
# 美金 (USD)      28.84    29.51    29.19    29.29  0.003
# 港幣 (HKD)      3.616     3.82    3.742    3.802  0.016
# 英鎊 (GBP)      36.08     38.2    37.08     37.5  0.011
# 澳幣 (AUD)      20.16    20.94    20.43    20.66  0.011
# 加拿大幣 (CAD)    21.35    22.26    21.74    21.96  0.010
# 新加坡幣 (SGD)    20.65    21.56    21.14    21.32  0.008
# 瑞士法郎 (CHF)    30.67    31.87    31.33    31.62  0.009
# 日圓 (JPY)     0.2676   0.2804   0.2749   0.2789  0.014
# 南非幣 (ZAR)   1000000  1000000    1.666    1.746  0.046
# 瑞典幣 (SEK)      2.82     3.34     3.16     3.26  0.031
# 紐元 (NZD)      18.66    19.51    19.04    19.24  0.010
# 泰幣 (THB)      0.797    0.987   0.9094   0.9494  0.042
# 菲國比索 (PHP)   0.5297   0.6627  1000000  1000000  0.000
# 印尼幣 (IDR)   0.00163  0.00233  1000000  1000000  0.000
# 歐元 (EUR)       33.2    34.54    33.82    34.22  0.012
# 韓元 (KRW)    0.02316  0.02706  1000000  1000000  0.000
# 越南盾 (VND)   0.00089  0.00139  1000000  1000000  0.000
# 馬來幣 (MYR)     5.898    7.523  1000000  1000000  0.000
# 人民幣 (CNY)     4.189    4.351    4.261    4.311  0.012

# %%
URL_2 = 'https://rate.bot.com.tw/ir?Lang=zh-TW'
s_rate = req.get(URL_2)
df_rate = pd.read_html(s_rate.text)

df_rate[0]
# Out:
#              幣別                    活期(年息%)                    定期存款 (年息%)  \
#              幣別 Unnamed: 1_level_1 活期(年息%) Unnamed: 3_level_1        7 天
# 0      美金 (USD)               0.05   0.100              0.100      0.100
# 1   美金 (USD) 大額                  -   0.100              0.100      0.100
# 2      港幣 (HKD)               0.05   0.100              0.100      0.100
# 3      英鎊 (GBP)               0.05   0.080              0.080      0.080
# 4      澳幣 (AUD)               0.01   0.050              0.050      0.050
# 5    加拿大幣 (CAD)               0.01   0.050              0.050      0.050
# 6    新加坡幣 (SGD)               0.05   0.100              0.100      0.100
# 7    瑞士法郎 (CHF)              0.001   0.001              0.001      0.001
# 8      日圓 (JPY)              0.001   0.001              0.001      0.001
# 9     南非幣 (ZAR)                0.7   1.700              1.700      1.700
# 10    瑞典幣 (SEK)              0.001   0.001              0.001      0.001
# 11     紐元 (NZD)               0.01   0.050              0.050      0.050
# 12     歐元 (EUR)              0.001   0.001              0.001      0.001
# 13    人民幣 (CNY)                0.1   0.300              0.300      0.300
#
#
#      14 天   21 天   1 個月   3 個月   6 個月 9 個月 1 年
# 0   0.120  0.200  0.300  0.350  0.400  NaN NaN
# 1   0.150  0.230  0.330  0.380  0.430  NaN NaN
# 2   0.200  0.300  0.400  0.450  0.550  NaN NaN
# 3   0.100  0.150  0.150  0.150  0.200  NaN NaN
# 4   0.100  0.200  0.300  0.320  0.350  NaN NaN
# 5   0.150  0.250  0.350  0.350  0.400  NaN NaN
# 6   0.100  0.150  0.200  0.300  0.300  NaN NaN
# 7   0.001  0.001  0.001  0.001  0.001  NaN NaN
# 8   0.001  0.001  0.001  0.001  0.002  NaN NaN
# 9   3.000  3.000  2.800  2.800  2.800  NaN NaN
# 10  0.001  0.001  0.001  0.001  0.001  NaN NaN
# 11  0.150  0.250  0.350  0.400  0.450  NaN NaN
# 12  0.001  0.001  0.001  0.001  0.002  NaN NaN
# 13  0.800  0.900  1.300  1.300  1.300  NaN NaN

# %%
df_rate_Final = pd.DataFrame({'定期年息':df_rate[0].iloc[:,-3].values/100},index=[i[:i.index(')')+1] for i in df_rate[0][('幣別','幣別')]])
df_rate_Final
# Out:
#                定期年息
# 美金 (USD)    0.00400
# 美金 (USD)    0.00430
# 港幣 (HKD)    0.00550
# 英鎊 (GBP)    0.00200
# 澳幣 (AUD)    0.00350
# 加拿大幣 (CAD)  0.00400
# 新加坡幣 (SGD)  0.00300
# 瑞士法郎 (CHF)  0.00001
# 日圓 (JPY)    0.00002
# 南非幣 (ZAR)   0.02800
# 瑞典幣 (SEK)   0.00001
# 紐元 (NZD)    0.00450
# 歐元 (EUR)    0.00002
# 人民幣 (CNY)   0.01300

# %%
df_rate_Final = df_rate_Final.iloc[[i!=1 for i in range(len(df_rate_Final.index))],:]

df_rate_Final
# Out:
#                定期年息
# 美金 (USD)    0.00400
# 港幣 (HKD)    0.00550
# 英鎊 (GBP)    0.00200
# 澳幣 (AUD)    0.00350
# 加拿大幣 (CAD)  0.00400
# 新加坡幣 (SGD)  0.00300
# 瑞士法郎 (CHF)  0.00001
# 日圓 (JPY)    0.00002
# 南非幣 (ZAR)   0.02800
# 瑞典幣 (SEK)   0.00001
# 紐元 (NZD)    0.00450
# 歐元 (EUR)    0.00002
# 人民幣 (CNY)   0.01300

# %%
df_coin['定期年息'] = df_rate_Final.iloc[:,0]

df_coin['獲益率(%)'] = (df_coin['定期年息']-df_coin['即期點差'])*100

df_coin.rename(columns={'即期點差':'即期匯率差'},inplace=True)

df_coin
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '即期點差'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-1f0720d879fd> in <module>
#       1 df_coin['定期年息'] = df_rate_Final.iloc[:,0]
#       2
# ----> 3 df_coin['獲益率(%)'] = (df_coin['定期年息']-df_coin['即期點差'])*100
#       4
#       5 df_coin.rename(columns={'即期點差':'即期匯率差'},inplace=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2797         if is_single_key:
#    2798             if self.columns.nlevels > 1:
# -> 2799                 return self._getitem_multilevel(key)
#    2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_multilevel(self, key)
#    2847     def _getitem_multilevel(self, key):
#    2848         # self.columns is a MultiIndex
# -> 2849         loc = self.columns.get_loc(key)
#    2850         if isinstance(loc, (slice, Series, np.ndarray, Index)):
#    2851             new_columns = self.columns[loc]
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in get_loc(self, key, method)
#    2660         if not isinstance(key, (tuple, list)):
#    2661             # not including list here breaks some indexing, xref #30892
# -> 2662             loc = self._get_level_indexer(key, level=0)
#    2663             return _maybe_to_slice(loc)
#    2664
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_level_indexer(self, key, level, indexer)
#    2927         else:
#    2928
# -> 2929             code = self._get_loc_single_level_index(level_index, key)
#    2930
#    2931             if level > 0 or self.lexsort_depth == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\multi.py in _get_loc_single_level_index(self, level_index, key)
#    2596             return -1
#    2597         else:
# -> 2598             return level_index.get_loc(key)
#    2599
#    2600     def get_loc(self, key, method=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '即期點差'

# %%
for i in range(df_coin.shape[0]):
    for j in range(df_coin.shape[1]):
        if df_coin.iloc[i,j] == 1000000:
            df_coin.iloc[i,j] = '-'

# %%
df_coin.rename(columns={'即期匯率差(%)':'即期匯率差'},inplace=True)

# %%
df_coin.to_excel("exchange.xlsx")
